# %%
import pandas as pd

# %%
df = pd.read_csv("heart_attack_dataset.csv")
df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0      Male   70                    181                  262           No
# 1    Female   55                    103                  253          Yes
# 2      Male   42                     95                  295          Yes
# 3      Male   84                    106                  270           No
# 4      Male   86                    187                  296          Yes
# ..      ...  ...                    ...                  ...          ...
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status   Chest Pain Type                            Treatment
# ...

# %%
df.head()
# Out:
#    Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0    Male   70                    181                  262           No
# 1  Female   55                    103                  253          Yes
# 2    Male   42                     95                  295          Yes
# 3    Male   84                    106                  270           No
# 4    Male   86                    187                  296          Yes
#
#   Smoking Status   Chest Pain Type                            Treatment
# 0          Never    Typical Angina                    Lifestyle Changes
# 1          Never   Atypical Angina                          Angioplasty
# 2        Current    Typical Angina                          Angioplasty
# 3          Never   Atypical Angina  Coronary Artery Bypass Graft (CABG)
# 4        Current  Non-anginal Pain                           Medication

# %%
df.tail()
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status   Chest Pain Type                            Treatment
# 995        Current    Typical Angina                          Angioplasty
# 996          Never   Atypical Angina  Coronary Artery Bypass Graft (CABG)
# 997        Current  Non-anginal Pain  Coronary Artery Bypass Graft (CABG)
# 998        Current      Asymptomatic                    Lifestyle Changes
# 999         Former   Atypical Angina                    Lifestyle Changes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 1000 non-null   object
#  1   Age                    1000 non-null   int64
#  2   Blood Pressure (mmHg)  1000 non-null   int64
#  3   Cholesterol (mg/dL)    1000 non-null   int64
#  4   Has Diabetes           1000 non-null   object
#  5   Smoking Status         1000 non-null   object
#  6   Chest Pain Type        1000 non-null   object
#  7   Treatment              1000 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#                Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)
# count  1000.000000            1000.000000          1000.000000
# mean     60.338000             145.440000           223.789000
# std      17.317496              31.756525            42.787817
# min      30.000000              90.000000           150.000000
# 25%      45.000000             118.000000           185.000000
# 50%      60.500000             146.000000           225.500000
# 75%      76.000000             173.000000           259.000000
# max      89.000000             199.000000           299.000000

# %%
df.dtypes
# Out:
# Gender                   object
# Age                       int64
# Blood Pressure (mmHg)     int64
# Cholesterol (mg/dL)       int64
# Has Diabetes             object
# Smoking Status           object
# Chest Pain Type          object
# Treatment                object
# dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#      Gender    Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  Has Diabetes  \
# 0     False  False                  False                False         False
# 1     False  False                  False                False         False
# 2     False  False                  False                False         False
# 3     False  False                  False                False         False
# 4     False  False                  False                False         False
# ..      ...    ...                    ...                  ...           ...
# 995   False  False                  False                False         False
# 996   False  False                  False                False         False
# 997   False  False                  False                False         False
# 998   False  False                  False                False         False
# 999   False  False                  False                False         False
#
# ...

# %%
df.isnull().sum()
# Out:
# Gender                   0
# Age                      0
# Blood Pressure (mmHg)    0
# Cholesterol (mg/dL)      0
# Has Diabetes             0
# Smoking Status           0
# Chest Pain Type          0
# Treatment                0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)  ###inplace == true
df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0      Male   70                    181                  262           No
# 1    Female   55                    103                  253          Yes
# 2      Male   42                     95                  295          Yes
# 3      Male   84                    106                  270           No
# 4      Male   86                    187                  296          Yes
# ..      ...  ...                    ...                  ...          ...
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status   Chest Pain Type                            Treatment
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Smoking Status']
# Out:
# 0        Never
# 1        Never
# 2      Current
# 3        Never
# 4      Current
#         ...
# 995    Current
# 996      Never
# 997    Current
# 998    Current
# 999     Former
# Name: Smoking Status, Length: 1000, dtype: object

# %%
df['Smoking Status'].unique()
# Out:
# array(['Never', 'Current', 'Former'], dtype=object)

# %%
df['Smoking Status'].value_counts()
# Out:
# Smoking Status
# Never      352
# Current    325
# Former     323
# Name: count, dtype: int64

# %%
df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0      Male   70                    181                  262           No
# 1    Female   55                    103                  253          Yes
# 2      Male   42                     95                  295          Yes
# 3      Male   84                    106                  270           No
# 4      Male   86                    187                  296          Yes
# ..      ...  ...                    ...                  ...          ...
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status   Chest Pain Type                            Treatment
# ...

# %%
df['Treatment'].unique()
# Out:
# array(['Lifestyle Changes', 'Angioplasty',
#        'Coronary Artery Bypass Graft (CABG)', 'Medication'], dtype=object)

# %%
Treatment_dict = {
    'Lifestyle Changes':1,
    'Angioplasty':2,
    'Coronary Artery Bypass Graft (CABG)':3,
    'Medication':4
}

# %%
Treatment_dict
# Out:
# {'Lifestyle Changes': 1,
#  'Angioplasty': 2,
#  'Coronary Artery Bypass Graft (CABG)': 3,
#  'Medication': 4}

# %%
df['Treatment']=df['Treatment'].map(Treatment_dict)

# %%
df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0      Male   70                    181                  262           No
# 1    Female   55                    103                  253          Yes
# 2      Male   42                     95                  295          Yes
# 3      Male   84                    106                  270           No
# 4      Male   86                    187                  296          Yes
# ..      ...  ...                    ...                  ...          ...
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status   Chest Pain Type  Treatment
# ...

# %%
df.dtypes
# Out:
# Gender                   object
# Age                       int64
# Blood Pressure (mmHg)     int64
# Cholesterol (mg/dL)       int64
# Has Diabetes             object
# Smoking Status           object
# Chest Pain Type          object
# Treatment                 int64
# dtype: object

# %%
df['Chest Pain Type'].unique()
# Out:
# array(['Typical Angina', 'Atypical Angina', 'Non-anginal Pain',
#        'Asymptomatic'], dtype=object)

# %%
chestpaintype_dict = {
    'Typical Angina':1,
    'Atypical Angina':2,
    'Non-anginal Pain':3,
    'Asymptomatic':4
}

# %%
chestpaintype_dict
# Out:
# {'Typical Angina': 1,
#  'Atypical Angina': 2,
#  'Non-anginal Pain': 3,
#  'Asymptomatic': 4}

# %%
df['Chest Pain Type']=df['Chest Pain Type'].map(chestpaintype_dict)

# %%
df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0      Male   70                    181                  262           No
# 1    Female   55                    103                  253          Yes
# 2      Male   42                     95                  295          Yes
# 3      Male   84                    106                  270           No
# 4      Male   86                    187                  296          Yes
# ..      ...  ...                    ...                  ...          ...
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#     Smoking Status  Chest Pain Type  Treatment
# ...

# %%
df.dtypes
# Out:
# Gender                   object
# Age                       int64
# Blood Pressure (mmHg)     int64
# Cholesterol (mg/dL)       int64
# Has Diabetes             object
# Smoking Status           object
# Chest Pain Type           int64
# Treatment                 int64
# dtype: object

# %%
df['Smoking Status'].unique()
# Out:
# array(['Never', 'Current', 'Former'], dtype=object)

# %%
SmokingStatus_dict = {'Never':1, 'Current':2, 'Former':3}

# %%
SmokingStatus_dict
# Out:
# {'Never': 1, 'Current': 2, 'Former': 3}

# %%
df['Smoking Status']=df['Smoking Status'].map(SmokingStatus_dict)

# %%
df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0      Male   70                    181                  262           No
# 1    Female   55                    103                  253          Yes
# 2      Male   42                     95                  295          Yes
# 3      Male   84                    106                  270           No
# 4      Male   86                    187                  296          Yes
# ..      ...  ...                    ...                  ...          ...
# 995    Male   42                    125                  193          Yes
# 996    Male   80                    186                  267          Yes
# 997  Female   64                    108                  174          Yes
# 998  Female   84                    123                  195           No
# 999    Male   61                    155                  197           No
#
#      Smoking Status  Chest Pain Type  Treatment
# ...

# %%
df['Gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3        Male
# 4        Male
#         ...
# 995      Male
# 996      Male
# 997    Female
# 998    Female
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    510
# Male      490
# Name: count, dtype: int64

# %%
Gender_dict = {
    'Male':1,
    'Female':2
}

# %%
Gender_dict
# Out:
# {'Male': 1, 'Female': 2}

# %%
df['Gender']=df['Gender'].map(Gender_dict)

# %%
df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL) Has Diabetes  \
# 0         1   70                    181                  262           No
# 1         2   55                    103                  253          Yes
# 2         1   42                     95                  295          Yes
# 3         1   84                    106                  270           No
# 4         1   86                    187                  296          Yes
# ..      ...  ...                    ...                  ...          ...
# 995       1   42                    125                  193          Yes
# 996       1   80                    186                  267          Yes
# 997       2   64                    108                  174          Yes
# 998       2   84                    123                  195           No
# 999       1   61                    155                  197           No
#
#      Smoking Status  Chest Pain Type  Treatment
# ...

# %%
df['Has Diabetes']
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3       No
# 4      Yes
#       ...
# 995    Yes
# 996    Yes
# 997    Yes
# 998     No
# 999     No
# Name: Has Diabetes, Length: 1000, dtype: object

# %%
df['Has Diabetes'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Has Diabetes'].value_counts()
# Out:
# Has Diabetes
# Yes    517
# No     483
# Name: count, dtype: int64

# %%
HasDiabetes_dict = {
    'Yes':1,
    'No':2
}

# %%
HasDiabetes_dict
# Out:
# {'Yes': 1, 'No': 2}

# %%
df['Has Diabetes']=df['Has Diabetes'].map(HasDiabetes_dict)

# %%
df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  Has Diabetes  \
# 0         1   70                    181                  262             2
# 1         2   55                    103                  253             1
# 2         1   42                     95                  295             1
# 3         1   84                    106                  270             2
# 4         1   86                    187                  296             1
# ..      ...  ...                    ...                  ...           ...
# 995       1   42                    125                  193             1
# 996       1   80                    186                  267             1
# 997       2   64                    108                  174             1
# 998       2   84                    123                  195             2
# 999       1   61                    155                  197             2
#
#      Smoking Status  Chest Pain Type  Treatment
# ...

# %%
df.dtypes
# Out:
# Gender                   int64
# Age                      int64
# Blood Pressure (mmHg)    int64
# Cholesterol (mg/dL)      int64
# Has Diabetes             int64
# Smoking Status           int64
# Chest Pain Type          int64
# Treatment                int64
# dtype: object

# %%
x = df.drop('Has Diabetes', axis = 1)
y = df[['Has Diabetes']]

# %%
x
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  Smoking Status  \
# 0         1   70                    181                  262               1
# 1         2   55                    103                  253               1
# 2         1   42                     95                  295               2
# 3         1   84                    106                  270               1
# 4         1   86                    187                  296               2
# ..      ...  ...                    ...                  ...             ...
# 995       1   42                    125                  193               2
# 996       1   80                    186                  267               1
# 997       2   64                    108                  174               2
# 998       2   84                    123                  195               2
# 999       1   61                    155                  197               3
#
#      Chest Pain Type  Treatment
# ...

# %%
y
# Out:
#      Has Diabetes
# 0               2
# 1               1
# 2               1
# 3               2
# 4               1
# ..            ...
# 995             1
# 996             1
# 997             1
# 998             2
# 999             2
#
# [1000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 42, test_size = 0.2)

# %%
x_train
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  Smoking Status  \
# 29        2   49                    159                  268               2
# 535       2   72                    167                  169               1
# 695       2   64                    119                  223               2
# 557       2   41                    150                  275               2
# 836       1   37                    155                  286               3
# ..      ...  ...                    ...                  ...             ...
# 106       2   78                    182                  166               1
# 270       2   72                    146                  157               1
# 860       2   65                    126                  246               1
# 435       2   47                    196                  159               2
# 102       2   32                    145                  256               3
#
#      Chest Pain Type  Treatment
# ...

# %%
x_test
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  Smoking Status  \
# 521       1   71                     99                  157               3
# 737       1   79                    192                  279               3
# 740       1   63                    157                  238               1
# 660       2   54                    134                  182               2
# 411       2   79                    106                  230               1
# ..      ...  ...                    ...                  ...             ...
# 408       2   69                    110                  162               3
# 332       2   64                     95                  285               3
# 208       2   48                    146                  167               3
# 613       2   82                     93                  235               3
# 78        1   45                    171                  150               2
#
#      Chest Pain Type  Treatment
# ...

# %%
y_train
# Out:
#      Has Diabetes
# 29              2
# 535             1
# 695             1
# 557             2
# 836             1
# ..            ...
# 106             2
# 270             2
# 860             2
# 435             1
# 102             1
#
# [800 rows x 1 columns]

# %%
y_test
# Out:
#      Has Diabetes
# 521             1
# 737             2
# 740             1
# 660             1
# 411             1
# ..            ...
# 408             2
# 332             2
# 208             2
# 613             1
# 78              2
#
# [200 rows x 1 columns]

# %%
x_test.shape,y_test.shape,x_train.shape,y_train.shape
# Out:
# ((200, 7), (200, 1), (800, 7), (800, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# -0.02031781236750807

# %%
pred=lr.predict(x_test)

# %%
pred
# Out:
# array([[1.43380413],
#        [1.46936586],
#        [1.57252695],
#        [1.42169403],
#        [1.49233664],
#        [1.44105103],
#        [1.58416066],
#        [1.48429693],
#        [1.50289622],
#        [1.50277538],
#        [1.52290581],
#        [1.496318  ],
#        [1.50993086],
#        [1.55910734],
#        [1.4141844 ],
#        [1.50509219],
#        [1.53129837],
#        [1.44599655],
#        [1.43288659],
#        [1.45098933],
#        [1.53001865],
#        [1.46637384],
#        [1.38833963],
#        [1.52227491],
#        [1.49439064],
#        [1.46141891],
#        [1.4386448 ],
#        [1.44220277],
#        [1.42489962],
#        [1.47686836],
#        [1.46345082],
#        [1.48989768],
#        [1.46146936],
#        [1.40727107],
#        [1.37868345],
#        [1.5154678 ],
#        [1.5417307 ],
#        [1.4426475 ],
#        [1.47813626],
#        [1.49521719],
#        [1.484836  ],
#        [1.44498869],
#        [1.47062377],
# ...
