# %%
import pandas as pd

# %%
df = pd.read_csv("laptopprice.csv")
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.tail()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
df.head(10)
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8  Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# ...

# %%
df.tail(10)
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 813    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 814    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 815    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 816    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 817    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.isnull()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)  ###inplace == true
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dropna()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['brand']
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 802, dtype: object

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
df['brand'].nunique()
# Out:
# 8

# %%
df['brand'].value_counts()
# Out:
# brand
# ASUS      243
# DELL      149
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      23
# Avita       6
# Name: count, dtype: int64

# %%
df.drop(['weight','Number of Reviews'],axis=1,inplace=True)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
brand_dict = {
    'ASUS':1,
    'DELL':2,
    'Lenovo':3,
    'HP':4,
    'acer':5,
    'MSI':6,
    'APPLE':7,      
    'Avita':8    
}

# %%
brand_dict
# Out:
# {'ASUS': 1,
#  'DELL': 2,
#  'Lenovo': 3,
#  'HP': 4,
#  'acer': 5,
#  'MSI': 6,
#  'APPLE': 7,
#  'Avita': 8}

# %%
df['brand']=df['brand'].map(brand_dict)

# %%
df
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0        1           Intel        Core i3            10th   4 GB     DDR4
# 1        3           Intel        Core i3            10th   4 GB     DDR4
# 2        3           Intel        Core i3            10th   4 GB     DDR4
# 3        1           Intel        Core i5            10th   8 GB     DDR4
# 4        1           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...             ...            ...             ...    ...      ...
# 818      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822      3             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb     warranty  \
# ...

# %%
df.dtypes
# Out:
# brand                 int64
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# dtype: object

# %%
df['processor_brand']
# Out:
# 0      Intel
# 1      Intel
# 2      Intel
# 3      Intel
# 4      Intel
#        ...
# 818      AMD
# 819      AMD
# 820      AMD
# 821      AMD
# 822      AMD
# Name: processor_brand, Length: 802, dtype: object

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# Intel    594
# AMD      189
# M1        19
# Name: count, dtype: int64

# %%
processor_brand_dict = {'Intel':1,
'AMD':2,
'M1':3 
}

# %%
processor_brand_dict
# Out:
# {'Intel': 1, 'AMD': 2, 'M1': 3}

# %%
df['processor_brand']=df['processor_brand'].map(processor_brand_dict)

# %%
df
# Out:
#      brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0        1                1        Core i3            10th   4 GB     DDR4
# 1        3                1        Core i3            10th   4 GB     DDR4
# 2        3                1        Core i3            10th   4 GB     DDR4
# 3        1                1        Core i5            10th   8 GB     DDR4
# 4        1                1   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...              ...            ...             ...    ...      ...
# 818      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 819      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 820      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 821      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 822      3                2        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['processor_name']
# Out:
# 0           Core i3
# 1           Core i3
# 2           Core i3
# 3           Core i5
# 4      Celeron Dual
#            ...
# 818         Ryzen 9
# 819         Ryzen 9
# 820         Ryzen 9
# 821         Ryzen 9
# 822         Ryzen 5
# Name: processor_name, Length: 802, dtype: object

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
df['processor_name'].value_counts()
# Out:
# processor_name
# Core i5         284
# Core i3         161
# Core i7         104
# Ryzen 5          82
# Ryzen 7          56
# Ryzen 9          26
# Ryzen 3          26
# Celeron Dual     23
# M1               19
# Pentium Quad     13
# Core i9           8
# Name: count, dtype: int64

# %%
processor_name_dict ={
    'Core i3':1,
    'Core i5':2,
    'Core i7':3,
    'Core i9':4,
    'Ryzen 3':5,
    'Ryzen 5':6,
    'Ryzen 7':7,
    'Ryzen 9':8,
    'M1':9,
    'Celeron Dual':10,
    'Pentium Quad':11
}

# %%
processor_name_dict
# Out:
# {'Core i3': 1,
#  'Core i5': 2,
#  'Core i7': 3,
#  'Core i9': 4,
#  'Ryzen 3': 5,
#  'Ryzen 5': 6,
#  'Ryzen 7': 7,
#  'Ryzen 9': 8,
#  'M1': 9,
#  'Celeron Dual': 10,
#  'Pentium Quad': 11}

# %%
df['processor_name']=df['processor_name'].map(processor_name_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name processor_gnrtn ram_gb ram_type  \
# 0        1                1               1            10th   4 GB     DDR4
# 1        3                1               1            10th   4 GB     DDR4
# 2        3                1               1            10th   4 GB     DDR4
# 3        1                1               2            10th   8 GB     DDR4
# 4        1                1              10   Not Available   4 GB     DDR4
# ..     ...              ...             ...             ...    ...      ...
# 818      1                2               8   Not Available   4 GB     DDR4
# 819      1                2               8   Not Available   4 GB     DDR4
# 820      1                2               8   Not Available   4 GB     DDR4
# 821      1                2               8   Not Available   4 GB     DDR4
# 822      3                2               6            10th   8 GB     DDR4
#
# ...

# %%
df.dtypes
# Out:
# brand                 int64
# processor_brand       int64
# processor_name        int64
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# dtype: object

# %%
df['processor_gnrtn']
# Out:
# 0               10th
# 1               10th
# 2               10th
# 3               10th
# 4      Not Available
#            ...
# 818    Not Available
# 819    Not Available
# 820    Not Available
# 821    Not Available
# 822             10th
# Name: processor_gnrtn, Length: 802, dtype: object

# %%
df['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
df['processor_gnrtn'].value_counts()
# Out:
# processor_gnrtn
# 11th             328
# Not Available    224
# 10th             198
# 8th               35
# 7th                7
# 9th                6
# 12th               3
# 4th                1
# Name: count, dtype: int64

# %%
processor_gnrtn_dict = {
    '4th':1,
    '7th':2,
    '8th':3,
    '9th':4,
    '10th':5,
    '11th':6,
    '12th':7,
    'not available':0
}

# %%
processor_gnrtn_dict
# Out:
# {'4th': 1,
#  '7th': 2,
#  '8th': 3,
#  '9th': 4,
#  '10th': 5,
#  '11th': 6,
#  '12th': 7,
#  'not available': 0}

# %%
df['processor_gnrtn']=df['processor_gnrtn'].map(processor_gnrtn_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn ram_gb ram_type  \
# 0        1                1               1              5.0   4 GB     DDR4
# 1        3                1               1              5.0   4 GB     DDR4
# 2        3                1               1              5.0   4 GB     DDR4
# 3        1                1               2              5.0   8 GB     DDR4
# 4        1                1              10              NaN   4 GB     DDR4
# ..     ...              ...             ...              ...    ...      ...
# 818      1                2               8              NaN   4 GB     DDR4
# 819      1                2               8              NaN   4 GB     DDR4
# 820      1                2               8              NaN   4 GB     DDR4
# 821      1                2               8              NaN   4 GB     DDR4
# 822      3                2               6              5.0   8 GB     DDR4
#
# ...

# %%
df.dtypes
# Out:
# brand                  int64
# processor_brand        int64
# processor_name         int64
# processor_gnrtn      float64
# ram_gb                object
# ram_type              object
# ssd                   object
# hdd                   object
# os                    object
# os_bit                object
# graphic_card_gb       object
# warranty              object
# Touchscreen           object
# msoffice              object
# Price                  int64
# rating                object
# Number of Ratings      int64
# dtype: object
